# %% [markdown]
# <a href="https://colab.research.google.com/github/EscarpitaS/SIMULACION/blob/main/Pruebas%20estad%C3%ADstica%20de%20uniformidad%20de%20Kolmogorov-Smirnov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# SEBASTIÁN ESCÁRPITA SÁNCHEZ
# Establecer seed
np.random.seed(23041008)

# Generar 100 números aleatorios entre 0 y 1
numeros_aleatorios = np.random.uniform(0, 1, 100)

# Realizar la prueba de uniformidad de Kolmogorov-Smirnov
# H0: Los datos siguen una distribución uniforme
# H1: Los datos no siguen una distribución uniforme
estadistico_ks, valor_p = stats.kstest(numeros_aleatorios, 'uniform')

# Imprimir resultados
print("Resultados de la prueba de uniformidad de Kolmogorov-Smirnov:")
print(f"Estadístico KS: {estadistico_ks:.4f}")
print(f"Valor p: {valor_p:.4f}")

# Visualizar los resultados
plt.figure(figsize=(10, 5))

# Histograma de los números aleatorios
plt.subplot(1, 2, 1)
plt.hist(numeros_aleatorios, bins=10, edgecolor='black')
plt.title('Histograma de los Números Aleatorios')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')

# Gráfico de la Función de Distribución Acumulativa (CDF)
plt.subplot(1, 2, 2)
datos_ordenados = np.sort(numeros_aleatorios)
y = np.arange(1, len(datos_ordenados) + 1) / len(datos_ordenados)
plt.step(datos_ordenados, y, label='CDF Empírica')
plt.plot(datos_ordenados, datos_ordenados, 'r--', label='CDF Uniforme')
plt.title('CDF Empírica vs CDF Uniforme')
plt.xlabel('Valor')
plt.ylabel('Probabilidad Acumulada')
plt.legend()

plt.tight_layout()
plt.show()

# Interpretación de los resultados
nivel_significancia = 0.05  # Nivel de significancia
print("\nInterpretación:")
if valor_p > nivel_significancia:
    print(f"No se rechaza H0 (valor p = {valor_p:.4f} > {nivel_significancia})")
    print("Los datos parecen estar distribuidos uniformemente.")
else:
    print(f"Se rechaza H0 (valor p = {valor_p:.4f} <= {nivel_significancia})")
    print("Los datos no parecen estar distribuidos uniformemente.")
# Out:
# Resultados de la prueba de uniformidad de Kolmogorov-Smirnov:
# Estadístico KS: 0.0422
# Valor p: 0.9911
# Interpretación:
# No se rechaza H0 (valor p = 0.9911 > 0.05)
# Los datos parecen estar distribuidos uniformemente.
